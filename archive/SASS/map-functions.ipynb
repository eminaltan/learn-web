# %% [markdown]
# #### Sass Map Functions
#
# Kaynak: [W3 Schools](https://www.w3schools.com/sass/sass_functions_map.php)
#
# SASS'da map'ler immutable özelliğe sahiptir. Yani map fonksiyonları yeni bir map döndürür. Orjinal map içeriği değiştirilemez.
#
# SASS'da map'ler `key`/`value` eşleşmesi ile oluşur.
#
# **Ex.**
#
# /* `small` burada key, `12px` ise value özelleğini ifade eder.*/
# `$font-size("small":12px)`
#
# **💡 SASS map fonskiyonları SASS liste fonksiyonları ile birlikte kullanılabilir. Kullanılması durumunda map, ikili değer şekinde liste gibi oluşacaktır. (`small:12px`, `medium:12px` gibi)**
#
# Aşağıda SASS'da kullanılan list yöntemlerine ve örneklerine yer verilmiştir.
#
# - `map-get(map, key)`: `map`'deki, `key`'a ait `value` bilgisini döndürür.
#
#     **Ex.**
#     `$font-size("small":12px, "norrmal":18px, "large":24px)`;
#
#     `map-get($font-size, "small")`; /* `small` key olarak ifade edilir.*/
#
#     Result: 12px
#
#
# - `map-has-key(map, key)`: `map`'de, `key`'in olup/olmadığını kontrol eder. Eğer `key`, `map` içerisinde tanımlı ise sonuç `true` aksi durumda `false` olarak döndürülür.
#
#     **Ex.**
#     `$font-size("small":12px, "norrmal":18px, "large":24px)`;
#
#     `map-get($font-size, "big")`; /* `big` key'ın map'e varlığı sorgulanıyor. */
#
#     Result: false
#
#
# - `map-keys(map)`: `map`'i oluşturan tüm `key`'leri listeler.
#
#     **Ex.**
#      `$font-size("small":12px, "norrmal":18px, "large":24px)`;
#
#      `map-keys($font-size)`;
#
#     Result: "small", "normal", "large"
#
#
# - `map-merge(map1, map2)`: `map2`'yi `map1`'in sonuna ekler.
#
#     **Ex.**
#     `$font-sizes: ("small": 12px, "normal": 18px, "large": 24px)`;
#     `$font-sizes2: ("x-large": 30px, "xx-large": 36px)`;
#
#     `map-merge($font-sizes, $font-sizes2)`;
#
#     Result: "small": 12px, "normal": 18px, "large": 24px, "x-large": 30px, "xx-large": 36px
#
#
# - `map-remove(map, keys...)`: `map`'den, `keys` ile belirtilen içeriği siler.
#
#     **Ex.**
#     `$font-sizes: ("small": 12px, "normal": 18px, "large": 24px)`;
#
#     `map-remove ($font-size, "small")`;
#
#     Result: ("normal": 18px, "large": 24px)
#
#
# - `map-values(map)`: `map`'i oluşturan `value`'ları listeler.
#
#     **Ex.**
#     `$font-size("small":12px , "normal": 18px, "large": 24px)`;
#
#     `map-values($font-size)`;
#
#     Result: 12px, 18px, 24px
